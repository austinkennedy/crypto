# %%
import pandas as pd
import os
import matplotlib

# %%
matched_trades = pd.read_csv('../temporary/matched_trades.csv', parse_dates = ['date'], infer_datetime_format = True)
matched_trades
# Out:
#                        date       tid        price    amount Currency  \
# 0       2017-03-15 00:00:24   6277292      1068.00  0.110000      GBP
# 1       2017-03-15 00:00:40   6277296      1062.93  0.117600      GBP
# 2       2017-03-15 00:00:49   6277295    547460.29  0.159900      NGN
# 3       2017-03-15 00:00:58   6277291      1526.72  0.039300      USD
# 4       2017-03-15 00:01:14   6277315     78740.16  0.012700      RUB
# ...                     ...       ...          ...       ...      ...
# 4883248 2022-09-27 22:44:19  56510120  84277182.39  0.001083      COP
# 4883249 2022-09-27 23:28:04  56510220    158900.00  0.002000      VED
# 4883250 2022-09-27 23:46:13  56510295   1227596.37  0.000407      RUB
# 4883251 2022-09-28 00:10:07  56510348  19417017.91  0.007210      CLP
# 4883252 2022-09-28 00:55:32  56510444    423109.39  0.004727      MXN
#
#          counter        tid2                date2   amount2 Currency2  \
# ...

# %%
def plot_series(data, currency_from, currency_to, date_from, date_to):
