# %%
import pandas as pd
import numpy as np
import os
from collections import Counter
pd.set_option("display.precision", 8)

# %%
trades = pd.read_csv('../temporary/trades_cleaned.csv', parse_dates = ['date'], infer_datetime_format = True)
trades
# Out:
#                         date       tid           price      amount Currency  \
# 0        2017-03-15 00:00:13   6277278  2.64900700e+04  0.07550000      MXN
# 1        2017-03-15 00:00:15    100281  4.12698413e+06  0.03150000      VEF
# 2        2017-03-15 00:00:15   6277265  1.29297000e+03  0.65740000      USD
# 3        2017-03-15 00:00:24   6277292  1.06800000e+03  0.11000000      GBP
# 4        2017-03-15 00:00:40   6277296  1.06293000e+03  0.11760000      GBP
# ...                      ...       ...             ...         ...      ...
# 42636057 2022-09-28 01:55:04  56510551  8.40412643e+07  0.00285574      COP
# 42636058 2022-09-28 01:55:10  56510558  1.80295800e+04  0.03189204      USD
# 42636059 2022-09-28 01:55:10  56510556  2.16994700e+04  0.00553009      USD
# 42636060 2022-09-28 01:57:02  56510553  2.00452200e+04  0.00249436      USD
# 42636061 2022-09-28 01:59:11  56510550  2.88917139e+07  0.00346120      KRW
#
#           counter
# 0               1
# ...

# %% [markdown]
# ## Get Distribution of Trade Sizes

# %%
freq = Counter(trades['amount'])
trade_sizes = pd.DataFrame(freq.items(), columns = ['trade_size', 'frequency'])
trade_sizes.sort_values(by = 'frequency')
trade_sizes
# Out:
#          trade_size  frequency
# 0        0.07550000        106
# 1        0.03150000        414
# 2        0.65740000          1
# 3        0.11000000       2384
# 4        0.11760000         46
# ...             ...        ...
# 7413009  0.13503517          1
# 7413010  0.02979257          1
# 7413011  0.07398786          1
# 7413012  0.15726642          1
# 7413013  0.03189204          1
#
# [7413014 rows x 2 columns]

# %%
K = len(trades) #gives amount of total trades ~40million
trade_sizes['p'] = trade_sizes['frequency']/K #unsure if this is right way to do it, but sum(p) = 1
trade_sizes
# Out:
#          trade_size  frequency           p
# 0        0.07550000        106  0.00000249
# 1        0.03150000        414  0.00000971
# 2        0.65740000          1  0.00000002
# 3        0.11000000       2384  0.00005592
# 4        0.11760000         46  0.00000108
# ...             ...        ...         ...
# 7413009  0.13503517          1  0.00000002
# 7413010  0.02979257          1  0.00000002
# 7413011  0.07398786          1  0.00000002
# 7413012  0.15726642          1  0.00000002
# 7413013  0.03189204          1  0.00000002
#
# [7413014 rows x 3 columns]

# %%
trade_sizes[trade_sizes['trade_size'] == 0.00202160]
# Out:
#         trade_size  frequency          p
# 813522   0.0020216         34  0.0000008

# %%
def get_trades(data, window):
    
    t = str(window) + 'h'
    
    data.sort_values(['amount', 'date'], inplace=True)
    data['tid2'] = data['tid'].shift(-1)
    data['date2'] = data['date'].shift(-1)
    data['amount2'] = data['amount'].shift(-1)
    data['Currency2'] = data['Currency'].shift(-1)
    data['time_diff'] = data['date2'] - data['date']
    df = data[(data['time_diff'] <= (t)) & (data['amount'] == data['amount2'])]
    
    return df

# def match_trades(data, interval):
#     window = str(interval) + 'h'
#     df = data[:10000000]
#     df1 = df['date', 'tid', 'amount']
#     df2 = df1.rename(columns=['date':'date2', 'tid':'tid2'])
    
#     merged = pd.merge(df1, df2, on='amount', how='')
    
#     # df = data.groupby(['amount', pd.Grouper(key = 'date', freq=frequency)])
#     data['matched'] = (data.groupby('amount')['date']
#                         .apply(lambda d: d['tid'].shift(-1) if d.shift(-1)(d.diff().shift(-1) <= pd.Timedelta(window) else 0)
#                         # .astype(int)
#                       )
                               
    # df = data.groupby('amount').filter() #look at timedeltas?
    # return data
    # data.resample(str(time)).agg({'counter':'sum'}) #also look at pandas.series.rolling

# %%
matched_trades = get_trades(trades, 5)
matched_trades
# Out:
#                         date       tid           price      amount Currency  \
# 0        2017-03-15 00:00:13   6277278  2.64900700e+04  0.07550000      MXN
# 1        2017-03-15 00:00:15   6277265  1.29297000e+03  0.65740000      USD
# 2        2017-03-15 00:00:24   6277292  1.06800000e+03  0.11000000      GBP
# 3        2017-03-15 00:00:40   6277296  1.06293000e+03  0.11760000      GBP
# 4        2017-03-15 00:00:42   6277268  1.79759000e+03  0.55630000      AUD
# ...                      ...       ...             ...         ...      ...
# 40127556 2022-09-28 01:55:04  56510551  8.40412643e+07  0.00285574      COP
# 40127557 2022-09-28 01:55:10  56510558  1.80295800e+04  0.03189204      USD
# 40127558 2022-09-28 01:55:10  56510556  2.16994700e+04  0.00553009      USD
# 40127559 2022-09-28 01:57:02  56510553  2.00452200e+04  0.00249436      USD
# 40127560 2022-09-28 01:59:11  56510550  2.88917139e+07  0.00346120      KRW
#
#           counter  matched
# 0               1        0
# ...

# %% [markdown]
# # Code Testing

# %%
# trades['tid2'] = 0
# test = trades[:10000000]
# group = test.groupby('amount')

# for g, df in group:
#     print(g)
#     # print(df)
#     i = 0
#     for ind, row in df.iterrows():
#         i += 1 #loop counter
#         if i%1000 == 0:
#             print('you finished another 1000 rows!')
#         for ind2, row2 in df.iterrows():
#             if row2['date'] <= row['date'] + pd.Timedelta('5h'):
#                 row['tid2'] = row2['tid']
# Out:
# 0.0001
# you finished another 1000 rows!
# you finished another 1000 rows!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [26], line 13
#      11 if i%1000 == 0:
#      12     print('you finished another 1000 rows!')
# ---> 13 for ind2, row2 in df.iterrows():
#      14     if row2['date'] <= row['date'] + pd.Timedelta('5h'):
#      15         row['tid2'] = row2['tid']
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:1324, in DataFrame.iterrows(self)
#    1322 klass = self._constructor_sliced
#    1323 for k, v in zip(self.index, self.values):
# -> 1324     s = klass(v, index=columns, name=k)
#    1325     yield k, s
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:451, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     449         data = data.copy()
#     450 else:
# ...

# %%
# for g, df in group:
#     print(g)
#     print(df)
#     print(df[df['tid2'] != 0])
# Out:
# 0.0001
#                        date       tid          price  amount Currency  \
# 18344   2017-03-16 09:53:24   6295278       108000.0  0.0001      RUB
# 37595   2017-03-17 14:34:35   6314399       120000.0  0.0001      RUB
# 45930   2017-03-18 00:49:58    102969      4030000.0  0.0001      VEF
# 123043  2017-03-23 16:32:14    107088      4006000.0  0.0001      VEF
# 225228  2017-03-30 22:24:08    113142      3942900.0  0.0001      VEF
# ...                     ...       ...            ...     ...      ...
# 9988319 2018-07-08 20:33:24   1284447  20450000000.0  0.0001      VEF
# 9988332 2018-07-08 20:34:08   1284449  20450000000.0  0.0001      VEF
# 9994121 2018-07-09 05:21:46  16236813       500000.0  0.0001      RUB
# 9994721 2018-07-09 06:17:12  16237360       590000.0  0.0001      RUB
# 9999094 2018-07-09 10:02:00  16241723       666500.0  0.0001      INR
#
#          counter  tid2
# 18344          1     0
# 37595          1     0
# 45930          1     0
# ...

# %%
test = trades[:10000000]
test['tid2'] = 0
group = test.groupby('amount')
test_group = group.get_group(0.0001)
# Out:
# C:\Users\Austin\AppData\Local\Temp\ipykernel_15492\2918189818.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['tid2'] = 0

# %%
import random
# test_group['tid_test'] = test_group['tid'].shift(-1)
test_group['bool_test'] = random.choices([True, False], k = len(test_group))
test_group['bool_result'] = test_group['bool_test'].where(True, test_group['tid'].shift(-1))
test_group
# Out:
# C:\Users\Austin\AppData\Local\Temp\ipykernel_15508\902634563.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group['bool_test'] = random.choices([True, False], k = len(test_group))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [26], line 4
#       2 # test_group['tid_test'] = test_group['tid'].shift(-1)
#       3 test_group['bool_test'] = random.choices([True, False], k = len(test_group))
# ----> 4 test_group['bool_result'] = test_group['bool_test'].where(True, test_group['tid'].shift(-1))
#       5 test_group
#
# ...

# %%
def get_tid(df, window):
    # if df['date'].diff().shift(-1) <= pd.Timedelta(window):
    #     df['tid2'] = df.diff()['tid']
    #https://stackoverflow.com/questions/48646684/pandas-conditional-shift
        df['matched_tid'] = (df.groupby('amount')['date']
                        .apply(lambda d: d['tid'].shift(-1) if (d.diff().shift(-1) <= pd.Timedelta(window)) else 0)
                        # .astype(int)
                      )

# %%
result = get_tid(test_group, 5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 result = get_tid(test_group, 5)
#
# Cell In [15], line 4, in get_tid(df, window)
#       1 def get_tid(df, window):
#       2     # if df['date'].diff().shift(-1) <= pd.Timedelta(window):
#       3     #     df['tid2'] = df.diff()['tid']
# ----> 4         df['matched_tid'] = (df.groupby('amount')['date']
#       5                         .apply(lambda d: d['tid'].shift(-1) if (d.diff().shift(-1) <= pd.Timedelta(window)) else 0)
#       6                         # .astype(int)
#       7                       )
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:244, in SeriesGroupBy.apply(self, func, *args, **kwargs)
#     238 @Appender(
#     239     _apply_docs["template"].format(
#     240         input="series", examples=_apply_docs["series_examples"]
#     241     )
#     242 )
# ...

# %%
def get_trades(data, window):
    
    t = str(window) + 'h'
    
    data.sort_values(['amount', 'date'], inplace=True)
    data['tid2'] = data['tid'].shift(-1)
    data['date2'] = data['date'].shift(-1)
    data['amount2'] = data['amount'].shift(-1)
    data['Currency2'] = data['Currency'].shift(-1)
    data['time_diff'] = data['date2'] - data['date']
    df = data[(data['time_diff'] <= (t)) & (data['amount'] == data['amount2'])]
    
    return df

# %%
matched = get_trades(trades, 5)
matched
# Out:
#                         date       tid       price        amount Currency  \
# 391382   2017-04-11 09:07:59   6665631    12100.00    0.00010000      SEK
# 394342   2017-04-11 12:59:13   6668557    69800.00    0.00010000      RUB
# 397921   2017-04-11 16:43:51    124343  7000000.00    0.00010000      VEF
# 430674   2017-04-13 19:29:19    126268  6000000.00    0.00010000      VEF
# 430905   2017-04-13 19:47:37    126281  6000000.00    0.00010000      VEF
# ...                      ...       ...         ...           ...      ...
# 6787452  2018-03-26 08:03:27  13042184     7233.53  138.24508919      EUR
# 6787457  2018-03-26 08:03:48  13042185     7233.53  138.24508919      EUR
# 6787481  2018-03-26 08:05:10  13042188     7011.27  142.62751256      EUR
# 18361628 2019-01-25 11:55:10  24804904     3094.44  161.58012435      EUR
# 5972259  2018-02-08 07:39:18  12229828     5333.11  187.50785189      EUR
#
#           counter        tid2               date2       amount2 Currency2  \
# ...

# %%
matched.sort_values('date')
# Out:
#                         date       tid        price      amount Currency  \
# 3        2017-03-15 00:00:24   6277292      1068.00  0.11000000      GBP
# 4        2017-03-15 00:00:40   6277296      1062.93  0.11760000      GBP
# 7        2017-03-15 00:00:49   6277295    547460.29  0.15990000      NGN
# 8        2017-03-15 00:00:58   6277291      1526.72  0.03930000      USD
# 11       2017-03-15 00:01:14   6277315     78740.16  0.01270000      RUB
# ...                      ...       ...          ...         ...      ...
# 42635627 2022-09-27 22:44:19  56510120  84277182.39  0.00108333      COP
# 42635745 2022-09-27 23:28:04  56510220    158900.00  0.00200000      VED
# 42635795 2022-09-27 23:46:13  56510295   1227596.37  0.00040730      RUB
# 42635845 2022-09-28 00:10:07  56510348  19417017.91  0.00721017      CLP
# 42635943 2022-09-28 00:55:32  56510444    423109.39  0.00472691      MXN
#
#           counter        tid2               date2     amount2 Currency2  \
# ...

# %%
test
# Out:
#                        date       tid       price        amount Currency  \
# 18344   2017-03-16 09:53:24   6295278   108000.00    0.00010000      RUB
# 37595   2017-03-17 14:34:35   6314399   120000.00    0.00010000      RUB
# 45930   2017-03-18 00:49:58    102969  4030000.00    0.00010000      VEF
# 123043  2017-03-23 16:32:14    107088  4006000.00    0.00010000      VEF
# 225228  2017-03-30 22:24:08    113142  3942900.00    0.00010000      VEF
# ...                     ...       ...         ...           ...      ...
# 5972254 2018-02-08 07:38:39  12229827     5399.45  185.20404856      EUR
# 5972259 2018-02-08 07:39:18  12229828     5333.11  187.50785189      EUR
# 5972267 2018-02-08 07:40:11  12229829     5333.11  187.50785189      EUR
# 5972248 2018-02-08 07:38:22  12229826     5240.12  190.83532438      EUR
# 6787490 2018-03-26 08:06:12  13042190     7011.27  285.25502512      EUR
#
#          counter        tid2               date2
# ...
